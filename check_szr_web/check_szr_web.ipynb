# %%
import urllib.request

# %%
response = urllib.request.urlopen('http://www.szrcr.cz/')
html = response.read()
print(html)
# Out:
# b'<!DOCTYPE html>\r\n<html lang="cs">\r\n<head>\r\n<script type="text/javascript">\n\n    var _gaq = _gaq || [];\n     _gaq.push(\n      [\'_setAccount\', \'UA-24348324-1\'],\n      [\'_setCustomVar\', 2, \'Weekday\', \'2\', 2],\n      [\'_trackPageview\'],\n      [\'_trackPageLoadTime\']\n    );\n\n        \n\n    (function() {\n      var ga = document.createElement(\'script\'); ga.type = \'text/javascript\'; ga.async = true;\n      ga.src = (\'https:\' == document.location.protocol ? \'https://ssl\' : \'http://www\') + \'.google-analytics.com/ga.js\';\n      var s = document.getElementsByTagName(\'script\')[0]; s.parentNode.insertBefore(ga, s);\n    })();\n  </script>\n<meta charset="UTF-8" />\r\n<meta name="viewport" content="width=device-width" />\r\n<meta http-equiv="content-type" content="text/html; charset=UTF-8" />\r\n<meta name="robots" content="index,follow" />\r\n<meta name="keywords" content="spr\xc3\xa1va z\xc3\xa1kladn\xc3\xadch registr\xc5\xaf, spr\xc3\xa1va registr\xc
# ...

# %%
from bs4 import BeautifulSoup
#soup = BeautifulSoup(urllib.request.urlopen('http://www.szrcr.cz/'), "html5lib")
soup = BeautifulSoup(urllib.request.urlopen('http://www.szrcr.cz/'), "lxml")
soup.find('marquee')
#list(soup.find(id="hp-text-scroll").children)
# Out:
# <marquee>
# </marquee>

# %%
soup2 = BeautifulSoup(urllib.request.urlopen('https://mdn.mozillademos.org/en-US/docs/Web/HTML/Element/marquee$samples/Examples?revision=1348080'),"lxml")
soup.find_all('marquee')
# Out:
# [<marquee>
#  </marquee>]

# %%
response = urllib.request.urlopen('https://mdn.mozillademos.org/en-US/docs/Web/HTML/Element/marquee$samples/Examples?revision=1348080')
html = response.read()
print(html)
# Out:
# b'<!DOCTYPE html>\n<html>\n    <head>\n        <link href="https://cdn.mdn.mozilla.net/static/build/styles/samples.37902ba3b7fe.css" rel="stylesheet" type="text/css" />\n        \n    </head>\n    <body>\n        \n            <marquee>This text will scroll from right to left</marquee>\n\n<marquee direction="up">This text will scroll from bottom to top</marquee>\n\n<marquee direction="down" width="250" height="200" behavior="alternate" style="border:solid">\n  <marquee behavior="alternate">\n    This text will bounce\n  </marquee>\n</marquee>\n        \n        \n    </body>\n</html>'
